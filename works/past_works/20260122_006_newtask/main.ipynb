# %% [markdown]
# # Delta_GPA 任务主笔记本
#
# 欢迎使用 Delta_GPA！这是一个用于生化反应热力学计算与预测的智能助手。
#
# ## 任务概述
#
# 在这里记录您的任务目标、方法和结果。
#
# ## 任务详情
#
# ### 生化条件
# - 温度 (T):
# - pH (氢离子浓度):
# - pMg (镁离子浓度):
# - 离子强度 (I):
#
# ### 使用的工具
# - 自由能预测方法:
#   - CC方法 (组分贡献法)
#   - GNN方法 (图神经网络)
#   - MC方法 (分片贡献法)
# - 数据库查询:
#   - KEGG
#   - PubChem
#
# ## 计算过程与结果
#
# 在此记录您的计算过程和结果。
